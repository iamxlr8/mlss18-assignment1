# %% [markdown]
# Welcome to your assignment on Pandas and Matplotlib!
# In case you face any difficulty or you have any doubts related to this assignment, or Pandas or Matplotlib in general, do not hesitate to ask on the Slack channel.

# %% [markdown]
# # Importing Libraries
#
# We shall start by importing the Python libraries you will need to run the code.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib

# %matplotlib inline

# %% [markdown]
# # Importing the Data
#
# Import the data stored in "day.csv" using Pandas and store it in a DataFrame named df.
# Also, since the data contains many columns that you may find unnecessary, you may drop them off.

# %%
#Fill in the incomplete code here
df = pd.read_csv("day.csv")
drop_list = ['instant', 'season', 'yr']
df.drop(drop_list,axis=1)
#Write code below to drop the columns given in drop_list. You can add or remove columns as per your convinience.
drop_list = ['instant', 'season', 'yr','mnth','holiday','weekday','workingday','weathersit','atemp','hum','windspeed']
df.drop(drop_list,axis=1)
# Out:
#          dteday      temp  casual  registered   cnt
# 0    2011-01-01  0.344167     331         654   985
# 1    2011-01-02  0.363478     131         670   801
# 2    2011-01-03  0.196364     120        1229  1349
# 3    2011-01-04  0.200000     108        1454  1562
# 4    2011-01-05  0.226957      82        1518  1600
# 5    2011-01-06  0.204348      88        1518  1606
# 6    2011-01-07  0.196522     148        1362  1510
# 7    2011-01-08  0.165000      68         891   959
# 8    2011-01-09  0.138333      54         768   822
# 9    2011-01-10  0.150833      41        1280  1321
# 10   2011-01-11  0.169091      43        1220  1263
# 11   2011-01-12  0.172727      25        1137  1162
# 12   2011-01-13  0.165000      38        1368  1406
# 13   2011-01-14  0.160870      54        1367  1421
# 14   2011-01-15  0.233333     222        1026  1248
# 15   2011-01-16  0.231667     251         953  1204
# 16   2011-01-17  0.175833     117         883  1000
# 17   2011-01-18  0.216667       9         674   683
# 18   2011-01-19  0.292174      78        1572  1650
# 19   2011-01-20  0.261667      83        1844  1927
# 20   2011-01-21  0.177500      75        1468  1543
# 21   2011-01-22  0.059130      93         888   981
# 22   2011-01-23  0.096522     150         836   986
# 23   2011-01-24  0.097391      86        1330  1416
# 24   2011-01-25  0.223478     186        1799  1985
# 25   2011-01-26  0.217500      34         472   506
# 26   2011-01-27  0.195000      15         416   431
# 27   2011-01-28  0.203478      38        1129  1167
# 28   2011-01-29  0.196522     123         975  1098
# 29   2011-01-30  0.216522     140         956  1096
# ..          ...       ...     ...         ...   ...
# 701  2012-12-02  0.347500     892        3757  4649
# 702  2012-12-03  0.452500     555        5679  6234
# 703  2012-12-04  0.475833     551        6055  6606
# 704  2012-12-05  0.438333     331        5398  5729
# 705  2012-12-06  0.255833     340        5035  5375
# 706  2012-12-07  0.320833     349        4659  5008
# 707  2012-12-08  0.381667    1153        4429  5582
# 708  2012-12-09  0.384167     441        2787  3228
# 709  2012-12-10  0.435833     329        4841  5170
# 710  2012-12-11  0.353333     282        5219  5501
# 711  2012-12-12  0.297500     310        5009  5319
# 712  2012-12-13  0.295833     425        5107  5532
# 713  2012-12-14  0.281667     429        5182  5611
# 714  2012-12-15  0.324167     767        4280  5047
# 715  2012-12-16  0.362500     538        3248  3786
# 716  2012-12-17  0.393333     212        4373  4585
# 717  2012-12-18  0.410833     433        5124  5557
# 718  2012-12-19  0.332500     333        4934  5267
# 719  2012-12-20  0.330000     314        3814  4128
# 720  2012-12-21  0.326667     221        3402  3623
# 721  2012-12-22  0.265833     205        1544  1749
# 722  2012-12-23  0.245833     408        1379  1787
# 723  2012-12-24  0.231304     174         746   920
# 724  2012-12-25  0.291304     440         573  1013
# 725  2012-12-26  0.243333       9         432   441
# 726  2012-12-27  0.254167     247        1867  2114
# 727  2012-12-28  0.253333     644        2451  3095
# 728  2012-12-29  0.253333     159        1182  1341
# 729  2012-12-30  0.255833     364        1432  1796
# 730  2012-12-31  0.215833     439        2290  2729
#
# [731 rows x 5 columns]

# %% [markdown]
# # Plotting the data
#
# With the data stored in our Pandas dataframe, we are now ready to plot the data to gain some insights on the data.
# We will define functions for each plot to make our code re-usable.

# %% [markdown]
# But before plotting, you must set some parameters common to all the plots. This is done in order to make the visibility and readability of the plots better. This can be done by changing the default rc settings defined in the matplotlibrc configuration files. One example is given.

# %%
#Set plot size to 14" x 7" (Solved Exapmle)
matplotlib.rc('figure', figsize = (14, 7))

#Set the font size to 15
matplotlib.rc('font',size=15)

#Do not display the top and right frame lines
matplotlib.rc('axes.spines', top=False,right=False)
#You can try experimenting with the background color, grid lines and font style
matplotlib.rc('polaraxes',grid=True)

# %% [markdown]
# ## Scatter Plot
#
# This is the most used plot for gaing insight into data while dealing with Machine Learning problems. For your convenience, the code for scatter plot is given as an exapmle.

# %%
def scatter_plot(x_data, y_data, x_label, y_label, title):
    
    fig, ax = plt.subplots()
    ax.scatter(x_data, y_data, s = 30, color = '#539caf', alpha = 0.75)
    
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    
scatter_plot(x_data = df['temp']
            , y_data = df['cnt']
            , x_label = 'Normalized temperature (C)'
            , y_label = 'Check outs'
            , title = 'Number of Check Outs vs Temperature')

# %% [markdown]
# # Histogram

# %%
#Fill the function given below
def histogram(data, x_label, y_label, title):
    fig, ax = plt.subplots()
    ax.hist(data,histtype='bar',rwidth=0.8)
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    plt.legend()
    
#Calling the function "histogram"
histogram(data = df['registered']
           , x_label = 'Check outs'
           , y_label = 'Frequency'
           , title = 'Distribution of Registered Check Outs')

# %% [markdown]
# # Line Plot

# %%
#Fill the function given below
def lineplot(x_data, y_data, x_label, y_label, title):
    fig, ax = plt.subplots()
    ax.plot(x_data,y_data,linewidth='1')
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    plt.legend()
    
#Calling the function to create plot
lineplot(x_data = df['dteday']
         , y_data = df['cnt']
         , x_label = 'Date'
         , y_label = 'Total Checkouts'
         , title = 'Total Checkouts for Each Day')

# %% [markdown]
# # Comparing Two Line Plots
#
# This is useful for comparing two variables over a third variable. It must be noted that these variables may have different scales (they do in the example given below).

# %%
#Fill the function given below
def lineplot2y(x_data, x_label, y1_data, y1_label, y2_data, y2_label, title):
    fig,ax=plt.subplots()
    ax.plot(x_data,y1_data,linewidth='1')
    ax.plot(x_data,y2_data,linewidth='1')
    ax.set_title(title)
    plt.legend()

#Calling the function to create plot
lineplot2y(x_data = df['dteday']
           , x_label = 'Date'
           , y1_data = df['casual']
           , y1_label = 'Casual Checkouts'
           , y2_data = df['registered']
           , y2_label = 'Registered Checkouts'
           , title = 'No. of Registered vs Casual Checkouts for Each Day')

# %% [markdown]
# # And You're Done!
#
# Congratulations on completing the second part of your first assignment. There are lots of plots you can explore and try on the numerous fields given in "day.csv". You can also do numpy operations on the data to derive more meaningful insights if you wish to.

# %% [markdown]
# You need to submit this Python notebook for this part of the assignment.
